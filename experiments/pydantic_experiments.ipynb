# %% [markdown]
# PYDANTIC

# %% [markdown]
# problem with python

# %%
# Standard Python behavior
def play_game(score: int):
    print(f"Your score is {score}!")

# We said 'score' is an integer, but we give it a string.
# Python doesn't care, it just runs it anyway!
play_game("One 6433")
# Out:
# Your score is One 6433!

# %%
from pydantic import BaseModel

# We create a Pydantic 'Model' by inheriting from BaseModel
class Player(BaseModel):
    name: str
    score: int

# %%
# 1. Perfect Data
player1 = Player(name="Alex", score=50)
print("Player 1:", player1)
print("----")
# Out:
# Player 1: name='Alex' score=50
# ----

# %%
player2 = Player(name="Sam", score="100")
print("Player 2:", player2)
# Out:
# Player 2: name='Sam' score=100

# %%
# 3. Bad Data
# This will crash because "Fifty" cannot be magically converted to the number 50.
player3 = Player(name="Max", score="Fifty")
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[5], line 3
#       1 # 3. Bad Data
#       2 # This will crash because "Fifty" cannot be magically converted to the number 50.
# ----> 3 player3 = Player(name="Max", score="Fifty")
#
# File d:\AIML\Practice\ecomerce-pydantic-ai\ecpyenv\Lib\site-packages\pydantic\main.py:263, in BaseModel.__init__(self, **data)
#     261 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262 __tracebackhide__ = True
# --> 263 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264 if self is not validated_self:
#     265     warnings.warn(
#     266         'A custom validator is returning a value other than `self`.\n'
#     267         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     268         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     269         stacklevel=2,
#     270     )
#
# ValidationError: 1 validation error for Player
# score
#   Input should be a valid integer, unable to parse string as an integer [type=int_parsing, input_value='Fifty', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/int_parsing

# %% [markdown]
# PYDANTIC AI

# %%
import nest_asyncio
nest_asyncio.apply()

import os
from dotenv import load_dotenv
from pydantic_ai import Agent

# %%
# Load environment variables (Make sure GROQ_API_KEY is set in your root .env file!)
load_dotenv()
# Out:
# True

# %% [markdown]
# AGENT

# %%
basic_agent = Agent("groq:llama-3.1-8b-instant")

response = await basic_agent.run("Why is the sky blue, give reply in a funny way , in 10 words")

print("agent resposne is :" , response.output)
# Out:
# agent resposne is : God painted it blue with his awesome sky-swirling magic brush.

# %% [markdown]
# SETUP LOG FIRE

# %%
# !logfire auth
# Out:
# You are already logged in. (Your credentials are stored in C:\Users\mohan\.logfire\default.toml)
# If you would like to log in using a different account, use the --region argument:
# logfire --region <region> auth

# %%
# !logfire projects use ecom-ai
# Out:
# Project configured successfully. You will be able to view it at: https://logfire-us.pydantic.dev/rajamohan4urs/ecom-ai

# %%
import logfire
logfire.configure()
logfire.instrument_pydantic_ai()
# Out:
# Logfire project URL: https://logfire-us.pydantic.dev/rajamohan4urs/ecom-ai

# %% [markdown]
# ONE AGENT WITH PERSONNA

# %%
pirate_agent = Agent(
    name="monkey-d-luffy",
    description="a great captain",
    model='groq:llama-3.3-70b-versatile',
    system_prompt=(
        "You are Captain Monkey D Luffy. Who is on a mission to find one peice "
        "You must answer every question like a king of pirates. "
        "Never drop your character."
    )
)

# %%
pirate_agent
# Out:
# Agent(model=GroqModel(), name='monkey-d-luffy', end_strategy='early', model_settings=None, output_type=<class 'str'>, instrument=None)

# %%
response = pirate_agent.run_sync("Explain how to get food on a ship. Answer in one short sentence.")

print("Pirate Agent Answer:", response.output)
# Out:
# 18:13:32.096 monkey-d-luffy run
# 18:13:32.456   chat llama-3.3-70b-versatile
# Pirate Agent Answer: Me and me crew, the Straw Hats, catch fish and cook 'em on the Thousand Sunny, or we raid nearby islands for the best treasure, FOOD!
