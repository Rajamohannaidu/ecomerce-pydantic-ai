# %%
from pymongo import MongoClient

# %%
client = MongoClient("mongodb+srv://xxxx:xxxxx@ecom-pydantic.igsh6v2.mongodb.net/?appName=ecom-pydantic")

# %%
db = client["ecom_db"]

collection = db["orders"]

print("connectted to mongo db")
# Out:
# connectted to mongo db

# %%
order = {
    "name": "Men Casual Shirt",
    "price": 999,
    "category": "men"
}

collection.insert_one(order)
# Out:
# InsertOneResult(ObjectId('69f49b2ad9ccf341ceaa7bbe'), acknowledged=True)

# %%
products = [
    {"name": "Jeans", "price": 1499, "category": "men"},
    {"name": "Kurti", "price": 999, "category": "women"},
    {"name": "Kids Jacket", "price": 1299, "category": "kids"}
]

collection.insert_many(products)

print("Multiple Products Inserted ✅")
# Out:
# Multiple Products Inserted ✅

# %%
# 🧪 🔹 CELL 6 — View All Products
all_products = collection.find()

for p in all_products:
    print(p)
# Out:
# {'_id': ObjectId('69f49b2ad9ccf341ceaa7bbe'), 'name': 'Men Casual Shirt', 'price': 999, 'category': 'men'}
# {'_id': ObjectId('69f49b54d9ccf341ceaa7bbf'), 'name': 'Jeans', 'price': 1499, 'category': 'men'}
# {'_id': ObjectId('69f49b54d9ccf341ceaa7bc0'), 'name': 'Kurti', 'price': 999, 'category': 'women'}
# {'_id': ObjectId('69f49b54d9ccf341ceaa7bc1'), 'name': 'Kids Jacket', 'price': 1299, 'category': 'kids'}

# %% [markdown]
# TEXT 2 Nosql

# %%
product = collection.find_one({"name": "Kurti"})

print(product)
# Out:
# {'_id': ObjectId('69f49b54d9ccf341ceaa7bc0'), 'name': 'Kurti', 'price': 999, 'category': 'women'}

# %%
men_products = collection.find({"category": "kids"})

for p in men_products:
    print(p)
# Out:
# {'_id': ObjectId('69f49b54d9ccf341ceaa7bc1'), 'name': 'Kids Jacket', 'price': 1299, 'category': 'kids'}

# %% [markdown]
# UPDATE

# %%
collection.update_one(
    {"name": "Jeans"},
    {"$set": {"price": 1399}}
)

print("Product Updated ✅")
# Out:
# Product Updated ✅

# %% [markdown]
# DELETE

# %%
collection.delete_one({"name": "Kids Jacket"})

print("Product Deleted ✅")
# Out:
# Product Deleted ✅

# %%
collection.delete_many({})

print("All Products Deleted ✅")
# Out:
# All Products Deleted ✅

# %%
collection.drop()

print("Collection Dropped ✅")
# Out:
# Collection Dropped ✅
